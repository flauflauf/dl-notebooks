# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
path = Path('data/horse-vs-zebra')
path.ls()
# Out:
# [PosixPath('data/horse-vs-zebra/zebra.csv'),
#  PosixPath('data/horse-vs-zebra/models'),
#  PosixPath('data/horse-vs-zebra/horse.csv'),
#  PosixPath('data/horse-vs-zebra/horse'),
#  PosixPath('data/horse-vs-zebra/zebra')]

# %% [markdown]
# Upload the URL files. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %%
classes = ['horse','zebra']

# %%
for c in classes:
    folder = str(c)
    file = folder + '.csv'
    dest = path/folder
    dest.mkdir(parents=True, exist_ok=True)
    print(path, file, dest)
    download_images(path/file, dest, max_pics=200)
# Out:
# data/horse-vs-zebra horse.csv data/horse-vs-zebra/horse
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:27<00:00]
#     </div>
# Error https://www.washingtonpost.com/resizer/BBWPaixqM_P8UYVhOoY04wyCrz8=/960x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/4ZYYZ7Q44U4ULJ7W4YRVY5XZCE.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://www.charlotteobserver.com/latest-news/10tpbe/picture216291950/alternates/FREE_1140/wildhorseherd.jpg HTTPSConnectionPool(host='www.charlotteobserver.com', port=443): Read timed out. (read timeout=4)
# Error https://www.blm.gov/adoptahorse/images/highlight/pintostud.jpg HTTPSConnectionPool(host='www.blm.gov', port=443): Read timed out. (read timeout=4)
# Error https://www.newsobserver.com/latest-news/zckbpd/picture217411370/alternates/FREE_1140/CWHF%20foal%205.jpg HTTPSConnectionPool(host='www.newsobserver.com', port=443): Read timed out. (read timeout=4)
# Error http://sciencenordic.com/sites/default/files/imagecache/300x/przewalskis_horse_03.jpg.crop_display.jpg HTTPConnectionPool(host='sciencenordic.com', port=80): Max retries exceeded with url: /sites/default/files/imagecache/300x/przewalskis_horse_03.jpg.crop_display.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f406a9f8da0>, 'Connection to sciencenordic.com timed out. (connect timeout=4)'))
# data/horse-vs-zebra zebra.csv data/horse-vs-zebra/zebra
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00]
#     </div>
# Error https://www.zoom-erlebniswelt.de/files/zoom/images/afrika/tiere/lexikon/grant-zebra-3.jpg HTTPSConnectionPool(host='www.zoom-erlebniswelt.de', port=443): Max retries exceeded with url: /files/zoom/images/afrika/tiere/lexikon/grant-zebra-3.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://www.zoom-erlebniswelt.de/files/zoom/images/afrika/tiere/lexikon/grant-zebra-2.jpg HTTPSConnectionPool(host='www.zoom-erlebniswelt.de', port=443): Max retries exceeded with url: /files/zoom/images/afrika/tiere/lexikon/grant-zebra-2.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://www.zoom-erlebniswelt.de/files/zoom/images/afrika/tiere/lexikon/grant-zebra-1.jpg HTTPSConnectionPool(host='www.zoom-erlebniswelt.de', port=443): Max retries exceeded with url: /files/zoom/images/afrika/tiere/lexikon/grant-zebra-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
# Error https://www.washingtonpost.com/resizer/vDVZlyHmDxEdl86h97SfL9Z09YY=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/BARVLJAP5U3LFH2WEUUZ74TK3M.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %%
for c in classes:
    dest = path/c
    print(len(dest.ls()))
# Out:
# 187
# 189

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# horse
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='187' class='' max='187', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [187/187 00:00<00:00]
#     </div>
# zebra
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='187' class='' max='187', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [187/187 00:00<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['horse', 'zebra']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['horse', 'zebra'], 2, 300, 74)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(6)
# Out:
# Total time: 00:21 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.865749</th>
#     <th>0.338880</th>
#     <th>0.189189</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.509579</th>
#     <th>0.010929</th>
#     <th>0.000000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.358455</th>
#     <th>0.001962</th>
#     <th>0.000000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.262969</th>
#     <th>0.000825</th>
#     <th>0.000000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.203095</th>
#     <th>0.000743</th>
#     <th>0.000000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.164397</th>
#     <th>0.000853</th>
#     <th>0.000000</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.unfreeze()

# %%
learn.lr_find(start_lr=1e-15, end_lr=1e-11)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 4.79E-15

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-6,3e-4))
# Out:
# Total time: 00:06 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.019121</th>
#     <th>0.001269</th>
#     <th>0.000000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.012812</th>
#     <th>0.001937</th>
#     <th>0.000000</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.most_confused()
# Out:
# []

# %%
interp.plot_top_losses(9, heatmap=True)

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:03<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device
# Out:
# device(type='cuda')

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'zebra'/'00000000.jpg')
img
# Out:
# Image (3, 333, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category zebra

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# Reset device to GPU:

# %%
defaults.device = torch.device('cuda')

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>15.858635</th>
#     <th>161265632.000000</th>
#     <th>0.445946</th>
#   </tr>
# </table>

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 00:16 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.978617</th>
#     <th>0.900335</th>
#     <th>0.554054</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.976146</th>
#     <th>0.862267</th>
#     <th>0.567568</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.951178</th>
#     <th>0.830188</th>
#     <th>0.527027</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.947020</th>
#     <th>0.811324</th>
#     <th>0.513514</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.908477</th>
#     <th>0.807303</th>
#     <th>0.513514</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.938917</th>
#     <th>7.510995</th>
#     <th>0.554054</th>
#   </tr>
# </table>

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 01:56 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.840469</th>
#     <th>0.694006</th>
#     <th>0.428571</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.789455</th>
#     <th>0.681246</th>
#     <th>0.416667</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.779555</th>
#     <th>0.664171</th>
#     <th>0.401786</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.767873</th>
#     <th>0.638714</th>
#     <th>0.348214</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.730677</th>
#     <th>0.604651</th>
#     <th>0.306548</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.674101</th>
#     <th>0.558960</th>
#     <th>0.238095</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.627371</th>
#     <th>0.505021</th>
#     <th>0.187500</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.575743</th>
#     <th>0.445338</th>
#     <th>0.122024</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.532960</th>
#     <th>0.385563</th>
#     <th>0.083333</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.494284</th>
#     <th>0.329154</th>
#     <th>0.056548</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.453943</th>
#     <th>0.280203</th>
#     <th>0.044643</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.416837</th>
#     <th>0.240172</th>
#     <th>0.038690</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.385421</th>
#     <th>0.207498</th>
#     <th>0.032738</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.356751</th>
#     <th>0.181117</th>
#     <th>0.029762</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.331578</th>
#     <th>0.161349</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.308677</th>
#     <th>0.145647</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.288259</th>
#     <th>0.132660</th>
#     <th>0.020833</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.270059</th>
#     <th>0.121990</th>
#     <th>0.020833</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.253881</th>
#     <th>0.114216</th>
#     <th>0.020833</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.239129</th>
#     <th>0.107490</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.225821</th>
#     <th>0.102434</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.213705</th>
#     <th>0.097664</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.202778</th>
#     <th>0.093757</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.192540</th>
#     <th>0.090622</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.183042</th>
#     <th>0.088651</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.174330</th>
#     <th>0.087324</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.166361</th>
#     <th>0.085108</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.158904</th>
#     <th>0.083667</th>
#     <th>0.020833</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.151887</th>
#     <th>0.083221</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.145359</th>
#     <th>0.082641</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.139287</th>
#     <th>0.081755</th>
#     <th>0.026786</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.133650</th>
#     <th>0.080920</th>
#     <th>0.026786</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.128366</th>
#     <th>0.079470</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.123316</th>
#     <th>0.079611</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.118603</th>
#     <th>0.078973</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.114192</th>
#     <th>0.078131</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.109982</th>
#     <th>0.078224</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.105978</th>
#     <th>0.078131</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.102214</th>
#     <th>0.078068</th>
#     <th>0.023810</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.098721</th>
#     <th>0.078102</th>
#     <th>0.023810</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()
